# %% [markdown]
# # Tarea 01: Jupyter y repaso de Python científico
#
# **Semana 1** · Entrega: antes de la clase de la Semana 2
#
# ## Objetivos de la tarea
#
# 1. Usar NumPy para calcular estadísticas básicas de un arreglo de datos.
# 2. Generar y operar arreglos de forma vectorizada (sin `for` explícito).
# 3. Practicar el flujo de trabajo de un notebook reproducible.

# %%
import numpy as np

# %% [markdown]
# ## Ejercicio 1 (caso base)
#
# En un experimento se midió la posición de un objeto 8 veces (en metros):
#
# ```python
# mediciones = np.array([2.3, 2.5, 2.1, 2.4, 2.6, 2.2, 2.5, 2.3])
# ```
#
# Calcula la **media** y la **desviación estándar** de `mediciones` usando
# NumPy (`np.mean`, `np.std`, con sus valores por defecto), y guarda los
# resultados en las variables `media` y `desviacion_estandar` — esos son los
# nombres que usa `tests/test_tarea.py` para calificar.

# %%
mediciones = np.array([2.3, 2.5, 2.1, 2.4, 2.6, 2.2, 2.5, 2.3])

# TODO: calcula media y desviacion_estandar con NumPy
media = ...
desviacion_estandar = ...

# %% [markdown]
# ## Ejercicio 2 (caso límite)
#
# Un objeto se mueve con aceleración constante (MRUA), con posición inicial
# $x_0$, velocidad inicial $v_0$ y aceleración $a$:
#
# $$x(t) = x_0 + v_0\, t + \tfrac{1}{2} a\, t^2$$
#
# Con `x0 = 0.0`, `v0 = 5.0`, `a = -9.8`:
#
# 1. Genera con `np.linspace` un arreglo `tiempos` de 50 puntos entre `0` y
#    `1`.
# 2. Calcula `posiciones`, aplicando la fórmula de arriba de forma
#    **vectorizada** (sin escribir un `for`), guardando el resultado con ese
#    nombre.
#
# Este ejercicio se califica igual que el ejercicio 1: el mismo
# concepto, pero exigiendo vectorización en vez de
# operar sobre un arreglo fijo.

# %%
x0 = 0.0
v0 = 5.0
a = -9.8

# TODO: genera tiempos con np.linspace y calcula posiciones de forma vectorizada
tiempos = ...
posiciones = ...

# %% [markdown]
# ## Resumen
#
# Esta tarea se califica de forma automática al entregar tu Pull Request.
# Antes de entregar, corre tu notebook completo (`Kernel → Restart & Run
# All`) y confirma que llega hasta el final sin errores.
