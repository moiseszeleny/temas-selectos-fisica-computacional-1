# %% [markdown]
# # Tarea <NN>: <TEMA>
#
# **Semana <NN>** · Entrega: <FECHA DE ENTREGA>
#
# ## Objetivos de la tarea
#
# 1. <objetivo 1>
# 2. <objetivo 2>
# 3. <objetivo 3>
#
# > Esta es la **plantilla genérica** de tarea. Reemplaza `<NN>`, `<TEMA>`,
# > `<FECHA DE ENTREGA>` y los objetivos; renombra el archivo con el número
# > real de semana (por ejemplo, `tarea-07.ipynb`) — `tests/conftest.py`
# > detecta el notebook por patrón, así que no hace falta tocarlo al
# > renombrar. Los dos ejercicios de ejemplo de abajo están resueltos
# > únicamente para que la plantilla se ejecute de punta a punta y sirva de
# > referencia de la mecánica de tests — **bórralos y sustitúyelos por el
# > enunciado real de la tarea**, dejando el código como `# TODO` para que lo
# > resuelva el estudiante.

# %%
import sympy as sp

sp.init_printing()

# %% [markdown]
# ## Ejercicio de ejemplo 1 (caso base)
#
# *Reemplaza este enunciado por el ejercicio real.* Calcula la derivada de
# $f(x) = x^3$ con respecto a $x$, y guarda el resultado en la variable
# `resultado_derivada` — ese nombre es el que usa `tests/test_tarea.py` para
# calificar, así que consérvalo si sigues usando esta plantilla tal cual, o
# actualízalo junto con el test si lo cambias.

# %%
# TODO: reemplaza este ejercicio de ejemplo por el ejercicio real de la tarea

# x es real (no complejo): así sp.diff da un resultado sin ramas de signo,
# y el test público puede comparar por igualdad simbólica directa.
x = sp.symbols('x', real=True)
f = x**3

resultado_derivada = sp.diff(f, x)
resultado_derivada

# %% [markdown]
# ## Ejercicio de ejemplo 2 (caso límite)
#
# *Reemplaza este enunciado por el ejercicio real.* Ahora calcula la derivada
# de $g(x) = x^n$ con $n$ simbólico (no numérico), y guarda el resultado en
# `resultado_derivada_general`. Este es el tipo de caso que conviene cubrir
# con un segundo test público (`test_tarea.py`): el mismo concepto que el
# ejercicio 1, pero en una situación más general.

# %%
# TODO: reemplaza este ejercicio de ejemplo por el ejercicio real de la tarea

# n positivo y entero (no un real cualquiera): así x**n tiene una derivada
# válida para todo x real sin casos especiales, y el test público puede
# verificarla con sp.simplify sin bifurcar en casos.
n = sp.symbols('n', positive=True, integer=True)
g = x**n

resultado_derivada_general = sp.diff(g, x)
resultado_derivada_general

# %% [markdown]
# ## Resumen
#
# Esta tarea se califica de forma automática al entregar tu Pull Request:
# los tests de `tests/test_tarea.py` cubren todas las habilidades evaluadas.
