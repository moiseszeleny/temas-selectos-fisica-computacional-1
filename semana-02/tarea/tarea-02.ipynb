# %% [markdown]
# # Tarea 02: Programación orientada a objetos
#
# **Semana 2** · Entrega: antes de la clase de la Semana 3
#
# ## Objetivos de la tarea
#
# 1. Definir una clase propia con atributos privados y propiedades de solo
#    lectura.
# 2. Sobrecargar operadores con métodos especiales (`__repr__`, `__eq__`,
#    `__add__`, `__mul__`).
# 3. Validar los datos de entrada al construir el objeto.

# %%
import math

# %% [markdown]
# ## Ejercicio 1 (caso base)
#
# Escribe una clase `Fraccion` que represente un número racional
# $\frac{a}{b}$. Estos son los nombres exactos que usa `tests/test_tarea.py`
# para calificar:
#
# - `__init__(self, numerador, denominador)` guarda los datos en
#   `self._numerador` y `self._denominador`. Si el denominador es `0`, debe
#   lanzar `ValueError` (una fracción con denominador cero no existe).
#   **No simplifiques aquí** — eso es del ejercicio 2.
# - `numerador` y `denominador`, como `@property` de **solo lectura** (sin
#   setter), igual que hicimos en clase con `Vector2D`. Una fracción es un
#   objeto matemático: una vez construida, no cambia.
# - `__repr__` devuelve exactamente el código que reconstruye el objeto. Para
#   `Fraccion(3, 4)` debe devolver la cadena `'Fraccion(3, 4)'` — con la coma
#   y el espacio tal cual.
# - `__eq__` compara **por valor**, con la multiplicación cruzada: $\frac{a}{b}
#   = \frac{c}{d}$ cuando $a\,d = c\,b$. Así, `Fraccion(1, 2) == Fraccion(2, 4)`
#   es `True`. Si `otro` no es una `Fraccion`, devuelve `NotImplemented`.

# %%
# TODO: completa la clase Fraccion del ejercicio 1
class Fraccion:

    def __init__(self, numerador, denominador):
        ...

    @property
    def numerador(self):
        ...

    @property
    def denominador(self):
        ...

    def __repr__(self):
        ...

    def __eq__(self, otro):
        ...

# %% [markdown]
# ## Ejercicio 2 (caso límite)
#
# Ahora dale aritmética propia. **Vuelve a escribir la clase completa** en la
# celda de abajo —como hicimos en clase, redefiniendo por capas— agregando
# dos métodos especiales:
#
# $$\frac{a}{b} + \frac{c}{d} = \frac{a\,d + c\,b}{b\,d}
# \qquad
# \frac{a}{b} \cdot \frac{c}{d} = \frac{a\,c}{b\,d}$$
#
# - `__add__(self, otro)` y `__mul__(self, otro)` devuelven una `Fraccion`
#   **nueva**, nunca modifican `self`.
# - El resultado debe quedar **normalizado**: reducido con `math.gcd`, y con
#   el signo siempre en el numerador. Por ejemplo,
#   `Fraccion(1, 2) * Fraccion(1, -3)` es `Fraccion(-1, 6)`, no
#   `Fraccion(1, -6)`.
#
# Puedes normalizar dentro de cada operador o en el constructor, como
# prefieras: los tests solo miran el resultado de las operaciones.
#
# > **Importante:** los tests califican la clase tal como queda definida en
# > esta celda, que es la última. Cópiate aquí tu solución del ejercicio 1 y
# > asegúrate de que la clase quede completa.

# %%
# TODO: copia tu solución del ejercicio 1 y agrega __add__ y __mul__ normalizados
class Fraccion:

    def __init__(self, numerador, denominador):
        ...

    @property
    def numerador(self):
        ...

    @property
    def denominador(self):
        ...

    def __repr__(self):
        ...

    def __eq__(self, otro):
        ...

    def __add__(self, otro):
        ...

    def __mul__(self, otro):
        ...

# %% [markdown]
# ## Resumen
#
# Entrega esta tarea en **Google Classroom** antes de la fecha indicada.
# Todavía no usamos Git ni GitHub para entregar — eso empieza en la semana 3.
#
# Antes de entregar, corre el notebook completo desde un kernel limpio
# (`Kernel → Restart & Run All`) y confirma que llega hasta el final sin
# errores.
